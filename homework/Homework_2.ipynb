# %% [markdown]
# ### 請在左上角的文件選單中複製一分到自己的 Google Drive。
# ![image.png](data:image/png;base64,...)
#
# ### 如果有遇到什麼問題，請把檔案分享連結貼到 Google Meet 聊天窗給助教看
# ![image.png](data:image/png;base64,...)
#
# ### 連結權限設為可編輯
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 學期結束了，小明想算一下自己的gpa
#
#
# **(請先執行這一格 code)**

# %%
# (請先執行這一格 code，這樣下面才看的到這些變數)

# 這是本學期小明修普通物理的所有成績

作業    = ["hw_1", "hw_2", "hw_3", "hw_4", "hw_5", "hw_6"]
作業成績 = [90    ,  92   , 88    ,  90   , 86    ,  80   ]

小考    = ["quiz_0915", "quiz_1001", "quiz_1015", "quiz_1101", "quiz_1115", "quiz_1201", "quiz_1215", "quiz_1230"]
小考成績 = [80         , 87         , 55         ,  65        ,  88        ,  90        , 45         , 70         ] 

期考    = ["exam_1", "exam_2", "exam_3"]
期考成績 = [88      , 79      ,  86     ]

# %% [markdown]
# 請問總共有幾次小考呢？請用 Lecture 2 學到的一個`list`函式，可以用來看一個`list`的長度
#
# (請不要直接數) (＞﹏＜)

# %%
# print 幾次小考
# TODO
print(?)
# Out:
# 8

# %% [markdown]
# 總成績的計算方式如下:<br>
# 作業成績（取平均）：20%<br>
# 小考成績 (取平均)：20%<br>
# 期考成績（取平均）：60%<br>
# <br>
# 請幫小明計算他普物最終的總成績～

# %%
# TODO
hw_mean = ?
quiz_mean = ?
exam_mean = ?

final_score = round(0.2 * hw_mean + 0.2 * quiz_mean + 0.6 * exam_mean,  0)

print("普物總成績：", final_score)
# Out:
# 普物總成績： 83.0

# %% [markdown]
# 以下是小明這學期所有科目及總成績：<br>
# <br>
# 3 大一國文 87
#
# 3 大一英文 92
#
# 2 微積分一 83
#
# 2 微積分二 88
#
# 3 計算機程式設計 78
#
# 3 離散數學 90
#
# 3 普通物理 83
#
# （前面數字代表學分數）

# %%
# 請執行這個cell

subject = ["大一國文", "大一英文", "微積分一", "微積分二", "計算機程式設計", "離散數學", "普通物理"]
score   = [87       ,  92      ,  83     ,  88      ,  78          ,  90      ,  83      ]

# %% [markdown]
# 等第績分換算：<br>
# <br>
# ![img](https://toolboxtw.com/images/calculator/gpa/gpa_convert_rule.png)<br>

# %%
# 請把score對照轉換成letter grade，再放入list "grade" 裡面

grade = []
for s in score:
    # 我們還沒有教到迴圈，可以想像s代表score裡面任一個item，我們要判斷這個item（一個數字）是位於哪個等第
    # TODO
    if ?: # 判斷s是否屬於A+
        # 將字串"A+"放入grade的「最後面」
    elif ?:
        
    .
    .
    .

    # tip: 以小明的成績來看，只需要check A+, A, A-, B 四種可能


print(grade)

# %% [markdown]
# End of the hw

# %%
# 將總成績換算成letter grade，結果寫成以下字串

s = "大一國文:A; 大一英文:A+; 微積分一:A-; 微積分二:A; 計算機程式設計:B; 離散數學:A+; 普通物理:A-"

# TODO
l = s.split(?) # 把各組「科目+等第」切開

subject, grade = [], [] # 一開始是空的

for item in l:
    # 還沒有教到for迴圈，可以想像在這裡我們把上面的list "l" 裡的每一項，也就是l[0], l[1], l[2], ..., l[i]依次做處理
    # 所以 item 是長成 "大一國文:A" 這樣的一個字串（舉例）(如果上一個TODO切對的話)
    # 目標是把 l 裡面的每一項「科目+等第」切開，分別放入subject和grade的「最後面」

    sub_list = item.split(':')
    # TODO
    科目 = sub_list[?]
    等第 = sub_list[?]
    # TODO
    # 變數「科目」和「等地」放入各自對應的list
    # tip: 用一個a開頭的函式

# 學分
credit = [3, 3, 2, 2, 3, 3, 3]

print("科目：", subject)
print("等第：", grade)
print("學分：", credit)
# Out:
#   Cell In[11], line 6
#     l = s.split(?) # 把各組「科目+等第」切開
#                 ^
# SyntaxError: invalid syntax

# %%
# 參考上圖，處理grade這個list，對應A+改成4.3，A對應4.0，...
# 將結果放入point這個list

point = []

for letter in grade:
    # TODO
    if ?: # 如果letter是A+
        point.append(4.3)
    elif ?:   
        point.append()
    .
    .
    .
    
    # tip: 以小明的成績來看，只需要check A+, A, A-, B 四種可能
    

print(point)
# Out:
# [0, 4.3, 0, 0, 0, 4.3, 0]

# %% [markdown]
# GPA就是等第積分(point)對學分數(credit)的加權平均，最後讓我們來幫小明計算GPA吧

# %%
# 計算GPA

# 先把point做加權處理
for i in range(len(point)):
    point[i] = point[i] * credit[i]

# TODO
total_point = ?
total_credit = ?

GPA = round(total_point / total_credit, 2)

print(GPA)
# Out:
# 1.36
